# %% [markdown]
# ## 2.2 Robustly Optimal Action

# %%
from src.plot import plot_simulatedpath_full2, plot_simulatedpath_uncer_decomp2

graph_title = """Figure 8: Simulated Pathways of R&D Investment as Percentage of GDP <br> The trajectories stop when temperature anomaly hit 1.5ᵒC """
plot_simulatedpath_full2(graph_type="RD_Plot", graph_title = graph_title, yaxis_label="%", graph_range=[0,10], before15=True)
# Out:
# <div>                            <div id="fe1b21cb-4b54-4ad2-a970-0ce6895febe7" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe1b21cb-4b54-4ad2-a970-0ce6895febe7")) {                    Plotly.newPlot(                        "fe1b21cb-4b54-4ad2-a970-0ce6895febe7",                        [{"line":{"color":"#d62728"},"name":"More Aversion","showlegend":false,"visible":false,"x":[0.0,0.08333333333333333,0.16666666666666666,0.25,0.3333333333333333,0.41666666666666663,0.5,0.5833333333333333,0.6666666666666666,0.75,0.8333333333333333,0.9166666666666666,1.0,1.0833333333333333,1.1666666666666665,1.25,1.3333333333333333,1.4166666666666665,1.5,1.5833333333333333,1.6666666666666665,1.75,1.8333333333333333,1.9166666666666665,2.0,2.083333333333333,2.16666666
# ...

# %%
from src.plot import plot_simulatedpath_full2, plot_simulatedpath_uncer_decomp2


graph_title = """Figure 9: Simulated Pathways of R&D Investment as Percentage of GDP <br> The trajectories stop when temperature anomaly hit 1.5ᵒC """
plot_simulatedpath_uncer_decomp2(graph_type="RD_Plot", graph_title = graph_title, yaxis_label="%", graph_range=[0,6], before15=True)
# Out:
# <div>                            <div id="65347b33-fcf3-4a24-80a0-325e2ec41fdd" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65347b33-fcf3-4a24-80a0-325e2ec41fdd")) {                    Plotly.newPlot(                        "65347b33-fcf3-4a24-80a0-325e2ec41fdd",                        [{"line":{"color":"#d62728"},"name":"Climate Uncertainty","showlegend":false,"visible":false,"x":[0.0,0.08333333333333333,0.16666666666666666,0.25,0.3333333333333333,0.41666666666666663,0.5,0.5833333333333333,0.6666666666666666,0.75,0.8333333333333333,0.9166666666666666,1.0,1.0833333333333333,1.1666666666666665,1.25,1.3333333333333333,1.4166666666666665,1.5,1.5833333333333333,1.6666666666666665,1.75,1.8333333333333333,1.9166666666666665,2.0,2.083333333333333,2.16
# ...

# %%
from src.plot import plot_simulatedpath_full2, plot_simulatedpath_uncer_decomp2


graph_title = """Figure 10: Simulated Pathways of Emissions <br> The trajectories stop when temperature anomaly hit 1.5ᵒC """
plot_simulatedpath_full2(graph_type="e", graph_title = graph_title, yaxis_label="", graph_range=[6,16], before15=True)
# Out:
# <div>                            <div id="99c3c40d-9642-44f4-a8f5-19fd4664a2cb" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("99c3c40d-9642-44f4-a8f5-19fd4664a2cb")) {                    Plotly.newPlot(                        "99c3c40d-9642-44f4-a8f5-19fd4664a2cb",                        [{"line":{"color":"#d62728"},"name":"More Aversion","showlegend":false,"visible":false,"x":[0.0,0.08333333333333333,0.16666666666666666,0.25,0.3333333333333333,0.41666666666666663,0.5,0.5833333333333333,0.6666666666666666,0.75,0.8333333333333333,0.9166666666666666,1.0,1.0833333333333333,1.1666666666666665,1.25,1.3333333333333333,1.4166666666666665,1.5,1.5833333333333333,1.6666666666666665,1.75,1.8333333333333333,1.9166666666666665,2.0,2.083333333333333,2.16666666
# ...

# %%
from src.plot import plot_simulatedpath_full2, plot_simulatedpath_uncer_decomp2

graph_title = """Figure 11: Simulated Pathways of Emissions <br> The trajectories stop when temperature anomaly hit 1.5ᵒC """
plot_simulatedpath_uncer_decomp2(graph_type="e", graph_title = graph_title, yaxis_label="", graph_range=[6,16], before15=True)
# Out:
# <div>                            <div id="2be466aa-0ab2-4c10-9a56-eda248aea311" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2be466aa-0ab2-4c10-9a56-eda248aea311")) {                    Plotly.newPlot(                        "2be466aa-0ab2-4c10-9a56-eda248aea311",                        [{"line":{"color":"#d62728"},"name":"Climate Uncertainty","showlegend":false,"visible":false,"x":[0.0,0.08333333333333333,0.16666666666666666,0.25,0.3333333333333333,0.41666666666666663,0.5,0.5833333333333333,0.6666666666666666,0.75,0.8333333333333333,0.9166666666666666,1.0,1.0833333333333333,1.1666666666666665,1.25,1.3333333333333333,1.4166666666666665,1.5,1.5833333333333333,1.6666666666666665,1.75,1.8333333333333333,1.9166666666666665,2.0,2.083333333333333,2.16
# ...

# %%
from src.plot import plot_simulatedpath_full2, plot_simulatedpath_uncer_decomp2

graph_title = """Figure 12: Simulated Pathways of Capital Investment as Percentage of GDP <br> The trajectories stop when temperature anomaly hit 1.5ᵒC """
plot_simulatedpath_full2(graph_type="CapIOutputRatio", graph_title = graph_title, yaxis_label="%", graph_range=[60,100], before15=True)
# Out:
# <div>                            <div id="7e904d75-6bc8-4f80-b6b5-be361abe4c95" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e904d75-6bc8-4f80-b6b5-be361abe4c95")) {                    Plotly.newPlot(                        "7e904d75-6bc8-4f80-b6b5-be361abe4c95",                        [{"line":{"color":"#d62728"},"name":"More Aversion","showlegend":false,"visible":false,"x":[0.0,0.08333333333333333,0.16666666666666666,0.25,0.3333333333333333,0.41666666666666663,0.5,0.5833333333333333,0.6666666666666666,0.75,0.8333333333333333,0.9166666666666666,1.0,1.0833333333333333,1.1666666666666665,1.25,1.3333333333333333,1.4166666666666665,1.5,1.5833333333333333,1.6666666666666665,1.75,1.8333333333333333,1.9166666666666665,2.0,2.083333333333333,2.16666666
# ...

# %%
from src.plot import plot_simulatedpath_full2, plot_simulatedpath_uncer_decomp2


graph_title = """Figure 13: Simulated Pathways of Capital Investment as Percentage of GDP <br> The trajectories stop when temperature anomaly hit 1.5ᵒC """
plot_simulatedpath_uncer_decomp2(graph_type="CapIOutputRatio", graph_title = graph_title, yaxis_label="%", graph_range=[60,100], before15=True)
# Out:
# <div>                            <div id="31ceba93-a4b3-44d5-b100-4aa4839fed0c" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31ceba93-a4b3-44d5-b100-4aa4839fed0c")) {                    Plotly.newPlot(                        "31ceba93-a4b3-44d5-b100-4aa4839fed0c",                        [{"line":{"color":"#d62728"},"name":"Climate Uncertainty","showlegend":false,"visible":false,"x":[0.0,0.08333333333333333,0.16666666666666666,0.25,0.3333333333333333,0.41666666666666663,0.5,0.5833333333333333,0.6666666666666666,0.75,0.8333333333333333,0.9166666666666666,1.0,1.0833333333333333,1.1666666666666665,1.25,1.3333333333333333,1.4166666666666665,1.5,1.5833333333333333,1.6666666666666665,1.75,1.8333333333333333,1.9166666666666665,2.0,2.083333333333333,2.16
# ...
