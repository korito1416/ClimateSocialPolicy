# %% [markdown]
# # 14 No Technology Uncertainty

# %%
from src.plot import plot_simulatedpath_uncer_decomp2_notech, plot_climatehist_notech, plot_gammahist_notech
 
graph_title = """Figure 48: Simulated Pathways of R&D Investment as Percentage of GDP <br> The trajectories stop when temperature anomaly hit 1.5ᵒC """
plot_simulatedpath_uncer_decomp2_notech(graph_type="RD_Plot", graph_title = graph_title, yaxis_label="%", graph_range=[0,6], before15=True)
# Out:
# <div>                            <div id="96ef3905-76bb-4685-ace1-0b2c23e825fd" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96ef3905-76bb-4685-ace1-0b2c23e825fd")) {                    Plotly.newPlot(                        "96ef3905-76bb-4685-ace1-0b2c23e825fd",                        [{"line":{"color":"#d62728"},"name":"Climate Uncertainty","showlegend":true,"visible":true,"x":[0.0,0.08333333333333333,0.16666666666666666,0.25,0.3333333333333333,0.41666666666666663,0.5,0.5833333333333333,0.6666666666666666,0.75,0.8333333333333333,0.9166666666666666,1.0,1.0833333333333333,1.1666666666666665,1.25,1.3333333333333333,1.4166666666666665,1.5,1.5833333333333333,1.6666666666666665,1.75,1.8333333333333333,1.9166666666666665,2.0,2.083333333333333,2.1666
# ...

# %%
graph_title = """Figure 49: Simulated Pathways of Emissions <br> The trajectories stop when temperature anomaly hit 1.5ᵒC """
plot_simulatedpath_uncer_decomp2_notech(graph_type="e", graph_title = graph_title, yaxis_label="", graph_range=[6,16], before15=True)
# Out:
# <div>                            <div id="a9535b07-1b22-466a-b480-0b79b59563ba" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9535b07-1b22-466a-b480-0b79b59563ba")) {                    Plotly.newPlot(                        "a9535b07-1b22-466a-b480-0b79b59563ba",                        [{"line":{"color":"#d62728"},"name":"Climate Uncertainty","showlegend":true,"visible":true,"x":[0.0,0.08333333333333333,0.16666666666666666,0.25,0.3333333333333333,0.41666666666666663,0.5,0.5833333333333333,0.6666666666666666,0.75,0.8333333333333333,0.9166666666666666,1.0,1.0833333333333333,1.1666666666666665,1.25,1.3333333333333333,1.4166666666666665,1.5,1.5833333333333333,1.6666666666666665,1.75,1.8333333333333333,1.9166666666666665,2.0,2.083333333333333,2.1666
# ...

# %%
title = "Figure 50: Distorted Probability of a Damage Jump"
plot_simulatedpath_uncer_decomp2_notech(graph_type="distorted_damage_prob", graph_title = title, yaxis_label="", graph_range=[0,1], before15=False)
# Out:
# <div>                            <div id="493f7467-c899-4ab1-9e57-bb41c5306a3a" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("493f7467-c899-4ab1-9e57-bb41c5306a3a")) {                    Plotly.newPlot(                        "493f7467-c899-4ab1-9e57-bb41c5306a3a",                        [{"line":{"color":"#d62728"},"name":"Climate Uncertainty","showlegend":true,"visible":true,"x":[0.0,0.08333333333333333,0.16666666666666666,0.25,0.3333333333333333,0.41666666666666663,0.5,0.5833333333333333,0.6666666666666666,0.75,0.8333333333333333,0.9166666666666666,1.0,1.0833333333333333,1.1666666666666665,1.25,1.3333333333333333,1.4166666666666665,1.5,1.5833333333333333,1.6666666666666665,1.75,1.8333333333333333,1.9166666666666665,2.0,2.083333333333333,2.1666
# ...

# %%
plot_climatehist_notech("Figure 51: Distorted climate model distribution")
# Out:
# <div>                            <div id="a50cd8bc-3bf3-42ed-8e2d-e13f1603a60d" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a50cd8bc-3bf3-42ed-8e2d-e13f1603a60d")) {                    Plotly.newPlot(                        "a50cd8bc-3bf3-42ed-8e2d-e13f1603a60d",                        [{"histnorm":"probability density","hovertemplate":"%{y:.2f}","name":"No Technology Uncentainty","opacity":0.5,"showlegend":true,"visible":true,"x":[2.1925822926219163,1.7437022926219168,1.7792022926219169,1.9742222926219166,1.7809322926219167,1.6051822926219168,2.1787422926219167,1.9152022926219168,1.7069522926219167,2.8015422926219165,2.2225822926219165,2.2683722926219168,2.5199122926219166,2.2706122926219163,2.0439222926219163,2.7837022926219164,2.443792292621
# ...

# %%
plot_gammahist_notech("""Figure 52: Distorted Climate Model Distribution""")
# Out:
# <div>                            <div id="35e9e234-75ce-4bcf-a96c-b030be1a9b84" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35e9e234-75ce-4bcf-a96c-b030be1a9b84")) {                    Plotly.newPlot(                        "35e9e234-75ce-4bcf-a96c-b030be1a9b84",                        [{"histfunc":"sum","histnorm":"probability","hovertemplate":"%{y:.2f}","name":"No technology Uncertainty","opacity":0.5,"showlegend":true,"visible":true,"x":[0.0,0.017543859649122806,0.03508771929824561,0.05263157894736842,0.07017543859649122,0.08771929824561403,0.10526315789473684,0.12280701754385964,0.14035087719298245,0.15789473684210525,0.17543859649122806,0.19298245614035087,0.21052631578947367,0.22807017543859648,0.24561403508771928,0.2631578947368421,0.280
# ...

# %%
title = """Figure 53: Simulated Pathways of Capital Distortion <br> The trajectories stop when temperature anomaly hit 1.5ᵒC"""
plot_simulatedpath_uncer_decomp2_notech(graph_type="hkt", graph_title = title, yaxis_label="", graph_range=[0,0.45], before15=True)
# Out:
# <div>                            <div id="741cd821-13cf-4738-b0dc-1dab4fc4879f" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("741cd821-13cf-4738-b0dc-1dab4fc4879f")) {                    Plotly.newPlot(                        "741cd821-13cf-4738-b0dc-1dab4fc4879f",                        [{"line":{"color":"#d62728"},"name":"Climate Uncertainty","showlegend":true,"visible":true,"x":[0.0,0.08333333333333333,0.16666666666666666,0.25,0.3333333333333333,0.41666666666666663,0.5,0.5833333333333333,0.6666666666666666,0.75,0.8333333333333333,0.9166666666666666,1.0,1.0833333333333333,1.1666666666666665,1.25,1.3333333333333333,1.4166666666666665,1.5,1.5833333333333333,1.6666666666666665,1.75,1.8333333333333333,1.9166666666666665,2.0,2.083333333333333,2.1666
# ...

# %%
title = """Figure 54: Simulated Pathways of Temperature Anomaly Distortion <br> The trajectories stop when temperature anomaly hit 1.5ᵒC"""
plot_simulatedpath_uncer_decomp2_notech(graph_type="ht", graph_title = title, yaxis_label="", graph_range=[0,0.45], before15=True)
# Out:
# <div>                            <div id="caa20909-a11b-446a-9851-9c85a45341f9" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("caa20909-a11b-446a-9851-9c85a45341f9")) {                    Plotly.newPlot(                        "caa20909-a11b-446a-9851-9c85a45341f9",                        [{"line":{"color":"#d62728"},"name":"Climate Uncertainty","showlegend":true,"visible":true,"x":[0.0,0.08333333333333333,0.16666666666666666,0.25,0.3333333333333333,0.41666666666666663,0.5,0.5833333333333333,0.6666666666666666,0.75,0.8333333333333333,0.9166666666666666,1.0,1.0833333333333333,1.1666666666666665,1.25,1.3333333333333333,1.4166666666666665,1.5,1.5833333333333333,1.6666666666666665,1.75,1.8333333333333333,1.9166666666666665,2.0,2.083333333333333,2.1666
# ...

# %%
title = """Figure 55: Simulated Pathways of the Technology Distortion <br> The trajectories stop when temperature anomaly hit 1.5ᵒC"""
plot_simulatedpath_uncer_decomp2_notech(graph_type="hjt", graph_title = title, yaxis_label="", graph_range=[0,0.45], before15=True)
# Out:
# <div>                            <div id="5e779961-481d-465c-addd-20014a504947" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e779961-481d-465c-addd-20014a504947")) {                    Plotly.newPlot(                        "5e779961-481d-465c-addd-20014a504947",                        [{"line":{"color":"#d62728"},"name":"Climate Uncertainty","showlegend":true,"visible":true,"x":[0.0,0.08333333333333333,0.16666666666666666,0.25,0.3333333333333333,0.41666666666666663,0.5,0.5833333333333333,0.6666666666666666,0.75,0.8333333333333333,0.9166666666666666,1.0,1.0833333333333333,1.1666666666666665,1.25,1.3333333333333333,1.4166666666666665,1.5,1.5833333333333333,1.6666666666666665,1.75,1.8333333333333333,1.9166666666666665,2.0,2.083333333333333,2.1666
# ...
